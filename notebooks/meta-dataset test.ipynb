# %%
# this notebook is just for testing if method of generation meta-dataset is OK

import sys
sys.path.append('../')

# %%
from src.datasets.metadataset import load_meta_dataset
from keras.datasets import cifar100
import numpy as np

(X_train, y_train), (X_test, y_test) = cifar100.load_data()
mean_image = np.mean(X_train, axis=0)
std_image = np.std(X_train, axis=0)

path = '../data/cifar100_64_64_2.h5'

meta_dataset = load_meta_dataset(path, X_train)
# Out:
# /home/mikolaj/anaconda3/envs/searching_minima/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt

ind = 10
s = meta_dataset.meta_train_set[ind]
print(s.train_set.x.shape)
print(s.train_set.y.shape)
print(s.test_set.x.shape)
print(s.test_set.y.shape)
    
print("TRAIN:")
for i in range(16):
    img = np.flip(s.train_set.x[i], axis=-1)
    print(s.train_set.y[i], np.max(img), np.min(img))
    fig, ax = plt.subplots(figsize=(2, 2))
    plt.imshow(img, interpolation='nearest')
    plt.show()
    
print("TEST:")
for i in range(16):
    img = np.flip(s.test_set.x[i], axis=-1)
    print(s.test_set.y[i], np.max(img), np.min(img))
    fig, ax = plt.subplots(figsize=(2, 2))
    plt.imshow(img, interpolation='nearest')
    plt.show()
# Out:
# (16, 32, 32, 3)
# (16, 2)
# (16, 32, 32, 3)
# (16, 2)
# TRAIN:
# [1. 0.] 0.7734375 0.1015625
# [1. 0.] 0.9921875 0.0
# [1. 0.] 0.9375 0.12109375
# [0. 1.] 0.98046875 0.0390625
# [1. 0.] 0.84765625 0.203125
# [0. 1.] 0.97265625 0.0
# [0. 1.] 0.96484375 0.0
# [0. 1.] 0.9921875 0.0625
# [1. 0.] 0.99609375 0.0
# [1. 0.] 0.97265625 0.08984375
# [1. 0.] 0.984375 0.00390625
# [1. 0.] 0.91796875 0.05859375
# [1. 0.] 0.93359375 0.015625
# [1. 0.] 0.69140625 0.015625
# [0. 1.] 0.96484375 0.0234375
# [1. 0.] 0.98828125 0.05078125
# TEST:
# [1. 0.] 0.6953125 0.0
# [0. 1.] 0.99609375 0.0
# [0. 1.] 0.92578125 0.0234375
# [0. 1.] 0.75390625 0.0859375
# [0. 1.] 0.99609375 0.0078125
# [0. 1.] 0.99609375 0.0
# [1. 0.] 0.98828125 0.0
# [0. 1.] 0.87890625 0.12109375
# [1. 0.] 0.99609375 0.04296875
# [0. 1.] 0.984375 0.03515625
# [0. 1.] 0.99609375 0.04296875
# [1. 0.] 0.84375 0.0
# [1. 0.] 0.8203125 0.0234375
# [0. 1.] 0.984375 0.00390625
# [0. 1.] 0.99609375 0.00390625
# [0. 1.] 0.8125 0.015625
